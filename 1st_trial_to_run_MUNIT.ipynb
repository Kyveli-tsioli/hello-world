# %% [markdown]
# <a href="https://colab.research.google.com/github/Kyveli-tsioli/hello-world/blob/main/1st_trial_to_run_MUNIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd drive/MyDrive/MUNIT
# Out:
# /content/drive/MyDrive/MUNIT

# %%
ls
# Out:
# configs/    docs/       models/       README.md      test.py      USAGE.md
# data.py     inputs/     networks.py   results/       trainer.py   utils.py
# datasets/   LICENSE.md  outputs/      scripts/       train.py
# Dockerfile  logs/       __pycache__/  test_batch.py  TUTORIAL.md

# %%
# !pip install tensorboardX

# %%
# !python test.py --config configs/edges2shoes_folder.yaml --input inputs/edges2shoes_edge.jpg --output_folder outputs --checkpoint models/edges2shoes.pt --a2b 1

# %%
# !python train.py --config configs/test_2nd_experiment.yaml
# Out:
# Streaming output truncated to the last 5000 lines.
# Elapsed time in update: 0.424177
# Elapsed time in update: 0.424158
# Elapsed time in update: 0.423821
# Elapsed time in update: 0.424071
# Elapsed time in update: 0.423736
# Elapsed time in update: 0.424590
# Iteration: 00000890/01000000
# Elapsed time in update: 0.424495
# Elapsed time in update: 0.424014
# Elapsed time in update: 0.424377
# Elapsed time in update: 0.424323
# Elapsed time in update: 0.424245
# Elapsed time in update: 0.423981
# Elapsed time in update: 0.424085
# Elapsed time in update: 0.424295
# Elapsed time in update: 0.423917
# Elapsed time in update: 0.424312
# Iteration: 00000900/01000000
# ...

# %%
# !python train.py --config configs/test_configuration.yaml
# Out:
# Traceback (most recent call last):
#   File "train.py", line 5, in <module>
#     from utils import get_all_data_loaders, prepare_sub_folder, write_html, write_loss, get_config, write_2images, Timer
#   File "/content/drive/MyDrive/MUNIT/utils.py", line 13
#     for images, viz., torchvision.datasets and torch.utils.data.DataLoader
#                     ^
# SyntaxError: invalid syntax

# %%
# !python train.py --config configs/edges2handbags_folder.yaml
# Out:
# Traceback (most recent call last):
#   File "train.py", line 5, in <module>
#     from utils import get_all_data_loaders, prepare_sub_folder, write_html, write_loss, get_config, write_2images, Timer
#   File "/content/drive/My Drive/MUNIT/utils.py", line 13
#     for images, viz., torchvision.datasets and torch.utils.data.DataLoader
#                     ^
# SyntaxError: invalid syntax

# %%
# !ls
# Out:
# configs     docs	 outputs      scripts	     train.py
# data.py     inputs	 __pycache__  test_batch.py  TUTORIAL.md
# datasets    LICENSE.md	 README.md    test.py	     USAGE.md
# Dockerfile  networks.py  results      trainer.py     utils.py

# %%
# !pip install torch==1.3.0 torchvision==0.4.1
# Out:
# ...
#      |████████████████████████████████| 773.1MB 24kB/s
# ...
#      |████████████████████████████████| 10.2MB 6.6MB/s
# ...
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.3.0 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# ...

# %%
from torch.utils.serialization import load_lua
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-dbcbb45dc083> in <module>()
# ----> 1 from torch.utils.serialization import load_lua
#
# ModuleNotFoundError: No module named 'torch.utils.serialization'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from torch.utils.data import DataLoader
